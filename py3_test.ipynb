# %%
import tensorflow

# %%
# !pyt
# Out:
# Python 2.7.12 :: Continuum Analytics, Inc.

# %%
dir(operator)
# Out:
# ['__abs__',
#  '__add__',
#  '__all__',
#  '__and__',
#  '__builtins__',
#  '__cached__',
#  '__concat__',
#  '__contains__',
#  '__delitem__',
#  '__doc__',
#  '__eq__',
#  '__file__',
#  '__floordiv__',
#  '__ge__',
#  '__getitem__',
#  '__gt__',
#  '__iadd__',
#  '__iand__',
#  '__iconcat__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__inv__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__loader__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__mul__',
#  '__name__',
#  '__ne__',
#  '__neg__',
#  '__not__',
#  '__or__',
#  '__package__',
#  '__pos__',
#  '__pow__',
#  '__rshift__',
#  '__setitem__',
#  '__spec__',
#  '__sub__',
#  '__truediv__',
#  '__xor__',
#  '_abs',
#  'abs',
#  'add',
#  'and_',
#  'attrgetter',
#  'concat',
#  'contains',
#  'countOf',
#  'delitem',
#  'eq',
#  'floordiv',
#  'ge',
# ...

# %%
# !conda python3 --version
# Out:
# Error: Could not locate 'conda-python3'

# %%
# !conda --version
# Out:
# conda 4.0.5

# %%
# !conda info --envs
# Out:
# Using Anaconda Cloud api site https://api.anaconda.org
# # conda environments:
# #
# python3                  /Users/MoonYongJoon/anaconda/envs/python3
# tensorflow            *  /Users/MoonYongJoon/anaconda/envs/tensorflow
# root                     /Users/MoonYongJoon/anaconda

# %%
# !conda search --full-name python
# Out:
# Using Anaconda Cloud api site https://api.anaconda.org
# Fetching package metadata: ....
# python                       1.0.1                         0  defaults
#                              2.6.8                         1  defaults
#                              2.6.8                         2  defaults
#                              2.6.8                         3  defaults
#                              2.6.8                         4  defaults
#                              2.6.8                         5  defaults
#                              2.6.8                         6  defaults
#                              2.6.8                         7  defaults
#                              2.6.8                         8  defaults
#                              2.6.8                         9  defaults
#                              2.6.8                        10  defaults
#                              2.6.9                         0  defaults
# ...

# %%
# !python3 --version
# Out:
# Python 3.5.1

# %%
# !python --version
# Out:
# Python 2.7.12 :: Continuum Analytics, Inc.

# %%
# !which python
# Out:
# /Users/MoonYongJoon/anaconda/envs/tensorflow/bin/python

# %%
# !which python3

# %%
# !cd /Library/Frameworks/Python.framework/Versions/3.5/bin/python3
# Out:
# /bin/sh: line 0: cd: /Library/Frameworks/Python.framework/Versions/3.5/bin/python3: Not a directory

# %%
# !conda list
# Out:
# # packages in environment at /Users/MoonYongJoon/anaconda/envs/tensorflow:
# #
# appnope                   0.1.0                    py27_0
# backports                 1.0                      py27_0
# backports-abc             0.4                       <pip>
# backports.shutil-get-terminal-size 1.0.0                     <pip>
# backports.ssl-match-hostname 3.4.0.2                   <pip>
# backports_abc             0.4                      py27_0
# certifi                   2016.2.28                 <pip>
# configparser              3.5.0                    py27_0
# cycler                    0.10.0                    <pip>
# decorator                 4.0.10                   py27_0
# entrypoints               0.2.2                    py27_0
# functools32               3.2.3.2                  py27_0
# future                    0.15.2                    <pip>
# futures                   3.0.5                     <pip>
# get_terminal_size         1.0.0                    py27_0
# ...

# %%
# !conda --name python3 list
# Out:
# Error: Could not locate 'conda-python3'

# %%
# !pip3 uninstall tensorflow
# Out:
# Uninstalling tensorflow-0.10.0rc0:
#   /Library/Frameworks/Python.framework/Versions/3.5/bin/tensorboard
#   /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/external/__init__.py
#   /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/external/__pycache__/__init__.cpython-35.pyc
#   /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/external/d3/d3.js
#   /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/external/d3/d3.min.js
#   /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/external/d3/package.js
#   /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/external/dagre/dist/dagre.core.js
#   /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/external/dagre/dist/dagre.core.min.js
# ...

# %%
# !pip3 list

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.show()
