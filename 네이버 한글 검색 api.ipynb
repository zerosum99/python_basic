# %%
key = "Tb8bzjtLVX7v5k_CPxOU"
password = "xqR4Fv6UEy"

# %%
import os
import sys
import urllib.request
import json

client_id = "Tb8bzjtLVX7v5k_CPxOU"
client_secret = "xqR4Fv6UEy"
encText = urllib.parse.quote("문용준")


ofile = open("data.json","w")


for i in range(5) :
    
    if i == 0 :
        start = 1
    else :
        start += 10
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText+"&start="+str(start)# json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_body.decode('utf-8')
        s = json.loads(response_body) # 문자열을 dict 타입으로 전환
        print(type(s))
        for items in s["items"] :
            #print(type(items))
            print((items['title']))
    else:
        print("Error Code:" + rescode)
# Out:
# <class 'dict'>
# 문재인 아들 <b>문용준</b> 특혜 논란 증거는 국민의당 당원...
# 소설가 반수연-<b>문용준</b> 기자의 차 한 잔 합시다 20
# 국민의당 이용주 단장은 <b>문용준</b> 특혜..
# [빅데이터] 빅 데이터란 가치를 찾는 것이다 – <b>문용준</b>...
# [청첩-알림]완도 장좌리 <b>문용준</b>, 김희자 의 장남 문정상...
# <b>문용준</b> 특혜사건  더있다
# 부산출장돌상,-<b>문용준</b>의 돌잔치가 서면롯데호텔 라센느에서...
# [데일리메일] [데일리메일]<b>문용준</b> 의혹조작 이유미 구속...
# &lt;티아라 바이 박은경&gt; <b>문용준</b> 신부님♥
# 인터넷 전문은행 사업 추진 방향성 6가지 - <b>문용준</b> SK C&amp;C 부장
# <class 'dict'>
# <b>문용준</b> <b>문용준</b>
# 세계 비보이 화려한 축제_<b>문용준</b>
# 국민의당 이유미 이준서 최종 설계자는 누구인가?
# 박지원,녹취록 조작은 중요하지 않아! 문제는 취업특혜야!
# [제주MBC 구성원 성명] 국토 최남단에서 외친다. 김장겸은...
# <b>문용준</b>님의 아기-인천아기사진 인천서구아기사진 가좌동...
# 밴쿠버15회한인문화의날-스완가드스테디엄
# [캐나다뉴스 &amp; CANADA NEWS] 한국인 방문자는 늘고...
# [데일리메일] [데일리메일]‘국민의당 <b>문용준</b> 조작 면죄부’준...
# 소통과 존중을 통한 시너지 극대화
# <class 'dict'>
# [금융전성시대, 인터넷은행 ]인터넷 전문은행 도입에 따른...
# [제59회 현충일 추념식] 더 머물다 가고 싶은 곳, 국립서울현충원
# 외식업창업성공사례,자전거를 탄 풍경,버들골 이야기 그 두번째...
# 블로그씨, 올해 일어났던 일 중, 내 인생에 가장 큰 영향을 준...
# 정두언 안철수 종쳤다 발언, 국민의당 정계 개편이 다가온다
# ...

# %%
ifile = open("data.json","r")

print(ifile)

for i in ifile :
    print(i)
# Out:
# <_io.TextIOWrapper name='data.json' mode='r' encoding='UTF-8'>
# ...

# %%
   """
        for data in response_body.decode('utf-8')['items'] :
            print(data)
            for i in len(data) :
                ofile.write(data[i]['title'])
        """

# %%
import os
import sys
import urllib.request
client_id = "Tb8bzjtLVX7v5k_CPxOU"
client_secret = "xqR4Fv6UEy"
encText = urllib.parse.quote("카뱅")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Fri, 08 Sep 2017 14:43:41 +0900",
# "total": 1720,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>카뱅</b> 프렌즈 체크카드 나도 있다!",
# "link": "http://blog.naver.com/joonim792?Redirect=Log&amp;logNo=221086700683",
# "description": "<b>카뱅</b> 프렌즈 체크카드 나도 있다 안녕하세요 줌마쏭이에요! 이제야 포스팅하게된 카카오뱅크 프렌즈 체크카드! 너무 갖고싶어서 혼났다요!! <b>카뱅</b> 체크카드 ! 카드이용 유의사항 및 <b>카뱅</b> 체크카드 개인회원... ",
# "bloggername": "줌마쏭 일상",
# "bloggerlink": "http://blog.naver.com/joonim792",
# "postdate": "20170831"
#
# },
# {
# "title": "<b>카뱅</b> 체크카드! 드디어 받았다!",
# "link": "http://blog.naver.com/archie?Redirect=Log&amp;logNo=221091134092",
# "description": "여기에 그간 넣어 다니던 카드를 빼고 <b>카뱅</b> 체카를 넣었다. 흠... 맘에 든다! 간단하게 여기까지만...^^ 내일부터는 교통카드도 이걸로 쓸 거다. 어차피 신용카드가 없으니 정말 이 카드 하나만 있으면 다 된다.... ",
# "bloggername": "즐거운 만물상",
# "bloggerlink": "http://blog.naver.com/archie",
# "postdate": "20170907"
#
# },
# {
# "title": "카카오뱅크 <b>카뱅</b> 체크카드 왔어요!",
# ...
