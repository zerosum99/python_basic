# %%
# !pip list
# Out:
# alabaster (0.7.9)
# anaconda-clean (1.0)
# anaconda-client (1.5.1)
# anaconda-navigator (1.3.1)
# argcomplete (1.0.0)
# astroid (1.4.7)
# astropy (1.2.1)
# Babel (2.3.4)
# backports.shutil-get-terminal-size (1.0.0)
# backports.weakref (1.0rc1)
# beautifulsoup4 (4.5.1)
# bitarray (0.8.1)
# blaze (0.10.1)
# bokeh (0.12.2)
# boto (2.42.0)
# Bottleneck (1.1.0)
# cffi (1.7.0)
# chest (0.2.3)
# click (6.7)
# cloudpickle (0.2.1)
# clyent (1.2.2)
# colorama (0.3.7)
# comtypes (1.1.2)
# conda (4.2.13)
# conda-build (2.0.2)
# configobj (5.0.6)
# contextlib2 (0.5.3)
# cryptography (1.5)
# cycler (0.10.0)
# Cython (0.24.1)
# cytoolz (0.8.0)
# dask (0.11.0)
# datashape (0.5.2)
# decorator (4.0.10)
# dill (0.2.5)
# docutils (0.12)
# dynd (c328ab7)
# et-xmlfile (1.0.1)
# fastcache (1.0.2)
# filelock (2.0.6)
# Flask (0.12)
# Flask-Cors (2.1.2)
# Flask-Script (2.0.5)
# Flask-WTF (0.14.2)
# gevent (1.1.2)
# greenlet (0.4.10)
# h5py (2.6.0)
# HeapDict (1.0.0)
# idna (2.1)
# imagesize (0.7.1)
# ...

# %%
# !pip install readline
# Out:
# ...
#     Complete output from command python setup.py egg_info:
#     error: this module is not meant to work on Windows
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in C:\Users\06411\AppData\Local\Temp\pip-build-p7wlfkd6\readline\

# %%
# !pip install tensorflow --upgrade
# Out:
# ...
#   Using cached bleach-1.5.0-py2.py3-none-any.whl
# ...
#   Running setup.py bdist_wheel for absl-py: started
#   Running setup.py bdist_wheel for absl-py: finished with status 'done'
#   Stored in directory: C:\Users\06411\AppData\Local\pip\Cache\wheels\d6\d5\fc\8405dfaa90e82a8665116b5058e14891c37b4a0a707e03b634
#   Running setup.py bdist_wheel for gast: started
#   Running setup.py bdist_wheel for gast: finished with status 'done'
#   Stored in directory: C:\Users\06411\AppData\Local\pip\Cache\wheels\8e\fa\d6\77dd17d18ea23fd7b860e02623d27c1be451521af40dd4a13e
#   Running setup.py bdist_wheel for termcolor: started
#   Running setup.py bdist_wheel for termcolor: finished with status 'done'
#   Stored in directory: C:\Users\06411\AppData\Local\pip\Cache\wheels\de\f7\bf\1bcac7bf30549e6a4957382e2ecab04c88e513117207067b03
# Successfully built absl-py gast termcolor
# ...
# Exception:
# Traceback (most recent call last):
# ...

# %%
# !pip list
# Out:
# alabaster (0.7.9)
# anaconda-clean (1.0)
# anaconda-client (1.5.1)
# anaconda-navigator (1.3.1)
# argcomplete (1.0.0)
# astroid (1.4.7)
# astropy (1.2.1)
# Babel (2.3.4)
# backports.shutil-get-terminal-size (1.0.0)
# backports.weakref (1.0rc1)
# beautifulsoup4 (4.5.1)
# bitarray (0.8.1)
# blaze (0.10.1)
# bokeh (0.12.2)
# boto (2.42.0)
# Bottleneck (1.1.0)
# cffi (1.7.0)
# chest (0.2.3)
# click (6.7)
# cloudpickle (0.2.1)
# clyent (1.2.2)
# colorama (0.3.7)
# comtypes (1.1.2)
# conda (4.2.13)
# conda-build (2.0.2)
# configobj (5.0.6)
# contextlib2 (0.5.3)
# cryptography (1.5)
# cycler (0.10.0)
# Cython (0.24.1)
# cytoolz (0.8.0)
# dask (0.11.0)
# datashape (0.5.2)
# decorator (4.0.10)
# dill (0.2.5)
# docutils (0.12)
# dynd (c328ab7)
# et-xmlfile (1.0.1)
# fastcache (1.0.2)
# filelock (2.0.6)
# Flask (0.12)
# Flask-Cors (2.1.2)
# Flask-Script (2.0.5)
# Flask-WTF (0.14.2)
# gevent (1.1.2)
# greenlet (0.4.10)
# h5py (2.6.0)
# HeapDict (1.0.0)
# idna (2.1)
# imagesize (0.7.1)
# ...

# %%
astor, numpy, six, absl-py, setuptools, protobuf, wheel, werkzeug, html5lib, bleach, markdown, tensorboard, gast, termcolor, grpcio, tensorflow

# %%
# !pip install six --upgrade
# Out:
# ...
#   Using cached six-1.11.0-py2.py3-none-any.whl
# ...
#   Found existing installation: six 1.10.0
#     Uninstalling six-1.10.0:
#     DEPRECATION: Uninstalling a distutils installed project (six) has been deprecated and will be removed in a future version. This is due to the fact that uninstalling a distutils project will only partially uninstall the project.
# Exception:
# Traceback (most recent call last):
#   File "C:\Program Files\Anaconda3\lib\shutil.py", line 538, in move
#     os.rename(src, real_dst)
# PermissionError: [WinError 5] 액세스가 거부되었습니다: 'c:\\program files\\anaconda3\\lib\\site-packages\\six-1.10.0-py3.5.egg-info' -> 'C:\\Users\\06411\\AppData\\Local\\Temp\\pip-08ot8gvp-uninstall\\program files\\anaconda3\\lib\\site-packages\\six-1.10.0-py3.5.egg-info'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\Anaconda3\lib\site-packages\pip\basecommand.py", line 215, in main
# ...

# %%
# !pip install python --upgrade
# Out:
# ...
#   Could not find a version that satisfies the requirement python (from versions: )
# No matching distribution found for python
