# %% [markdown]
# ## matpoltlib 중에 animation 처리
#
# %matplotlib notebook: qt 창을 inline으로 처리해야 함

# %%
# %matplotlib notebook

from matplotlib import animation
from matplotlib import pyplot as plt

circle = plt.Circle((0,0), 0.05)

def update_radius(i, circle):
    circle.radius = i * 0.5
    return circle

fig = plt.gcf()

ax = plt.axes(xlim=(-10,10), ylim=(-10,10))
ax.set_aspect('equal')
ax.add_patch(circle)

ani = animation.FuncAnimation(fig, update_radius, fargs = (circle,), frames = 30, interval=50)

plt.title('Simple Circle Animation')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
# %matplotlib inline
import numpy as np
data = np.random.rand(100,2)
print type(data)
print data.shape

plt.scatter(data[:50,0],data[50:,0], color='b')
plt.scatter(data[:50,1],data[50:,1], color='r')
plt.show()
# Out:
# <type 'numpy.ndarray'>
# (100, 2)
