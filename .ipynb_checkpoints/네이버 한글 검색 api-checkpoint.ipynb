# %%
key = "Tb8bzjtLVX7v5k_CPxOU"
password = "xqR4Fv6UEy"

# %%
import os
import sys
import urllib.request
import json

client_id = "Tb8bzjtLVX7v5k_CPxOU"
client_secret = "xqR4Fv6UEy"
encText = urllib.parse.quote("문용준")


ofile = open("data.json","w")


for i in range(5) :
    
    if i == 0 :
        start = 1
    else :
        start += 10
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText+"&start="+str(start)# json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        ofile.write(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)

# %%
ifile = open("data.json","r")

print(ifile)

for i in ifile :
    print(i)
# Out:
# <_io.TextIOWrapper name='data.json' mode='r' encoding='UTF-8'>
# {
#
# "lastBuildDate": "Fri, 08 Sep 2017 13:54:41 +0900",
#
# "total": 518,
#
# "start": 1,
#
# "display": 10,
#
# "items": [
#
# {
#
# "title": "문재인 아들 <b>문용준</b> 특혜 논란 증거는 국민의당 당원... ",
#
# "link": "http://blog.naver.com/yang456?Redirect=Log&amp;logNo=221038405002",
#
# "description": "문재인 아들 <b>문용준</b> 특혜 논란… 정우택&quot;흙수저 대변한다더니 금수저 행세&quot; - 이뉴스투데이 [이뉴스투데이 정영미 기자] 문재인 전 후보의 아들 <b>문용준</b>씨의 특혜 논란과 관련해 정우택 자유한국당 원내대표가... ",
#
# "bloggername": "소년의 마음을 가진 아저씨를 위한 장난감 나라",
#
# "bloggerlink": "http://blog.naver.com/yang456",
#
# "postdate": "20170627"
#
#
#
# },
#
# {
#
# "title": "소설가 반수연-<b>문용준</b> 기자의 차 한 잔 합시다 20",
#
# "link": "http://blog.daum.net/chkwon1004/18357731",
#
# "description": "“쓰리고 쓸쓸한 이민생활, 무엇이 그대의 위로였습니까?” <b>문용준</b> 기자 ***@*********.*** 기자의 다른 기사보기 최종수정 : 2015-08-28 11:54 <b>문용준</b> 기자의 차 한 잔 합시다 20, 소설가 반수연 그녀의 이민생활은 만만치... ",
#
# "bloggername": "학 마 을",
#
# "bloggerlink": "http://blog.daum.net/chkwon1004",
#
# "postdate": "20150829"
#
#
#
# },
#
# {
#
# "title": "국민의당 이용주 단장은 <b>문용준</b> 특혜..",
#
# "link": "http://blog.naver.com/kuht119?Redirect=Log&amp;logNo=220992910709",
#
# "description": "국민의당 이용주 단장은 <b>문용준</b> 특혜채용을 위해 강씨를 비롯한 12명의 계약직 직원을 계약해지하고 이에 강씨등이 항의하여 <b>문용준</b> 특혜채용에 대해 비밀계약으로 재계약을 했다한다. 1. <b>문용준</b>은 일반직... ",
#
# "bloggername": "kuht119님의 블로그",
#
# "bloggerlink": "http://blog.naver.com/kuht119",
#
# "postdate": "20170426"
#
#
#
# },
#
# {
#
# "title": "[빅데이터] 빅 데이터란 가치를 찾는 것이다 – <b>문용준</b>... ",
#
# "link": "http://blog.naver.com/zerosum99?Redirect=Log&amp;logNo=220132132908",
#
# "description": "[빅데이터] 빅 데이터란 가치를 찾는 것이다 – <b>문용준</b> 빅데이터 아키텍처 2013년 12월 25일 | Filed under: 칼럼 | Posted by: IT News <b>문용준</b> 빅데이터 아키텍처 - SK C&amp;C 부장 - 금융 차세대 프로젝트 및 IFRS 프로젝트 수행... ",
#
# "bloggername": "락(樂)을 즐겨라!",
#
# "bloggerlink": "http://blog.naver.com/zerosum99",
#
# "postdate": "20140925"
#
#
#
# },
#
# {
#
# "title": "[청첩-알림]완도 장좌리 <b>문용준</b>, 김희자 의 장남 문정상... ",
#
# "link": "http://blog.daum.net/jcpost/11306057",
#
# "description": "[청첩-알림]완도 장좌리 <b>문용준</b>, 김희자 의 장남 문정상(청해초등학교 동문회) 결혼식 안내 완도 장좌리 <b>문용준</b>, 김희자 의 장남 문정상 군 황귀성, 박성자 의 장남 김헤숙 양 일시 : 2010년 3월 6일(음력 1월... ",
#
# "bloggername": "jc1300 완도 진우상회",
#
# "bloggerlink": "http://blog.daum.net/jcpost",
#
# "postdate": "20100301"
#
#
#
# },
#
# {
#
# "title": "<b>문용준</b> 특혜사건  더있다",
#
# "link": "http://blog.naver.com/spacwolf?Redirect=Log&amp;logNo=220990925305",
#
# "description": "일하는 정당 - 국민의당 http://me2.do/FPIVlS1l 일하는 정당 - 국민의당 04/24 [기자회견문] 이용주 공명선거추진단장, 고용정보원 ‘문준용’식 특혜채용 10여건 발견 고용정보원 ‘문준용’식 특혜채용... ",
#
# "bloggername": "풍류묵향",
#
# "bloggerlink": "http://blog.naver.com/spacwolf",
#
# "postdate": "20170424"
#
#
#
# },
#
# {
#
# "title": "부산출장돌상,-<b>문용준</b>의 돌잔치가 서면롯데호텔 라센느에서... ",
#
# "link": "http://blog.daum.net/sodam2/6930888",
#
# "description": "2012.9.9 서면 롯데호텔 라센느에서 <b>문용준</b>이 돌잔치가 있었습니다. 파티해월,부산돌잔치업체,해운대돌잔치,부산전통돌잔치,부산전통돌상,부산돌산출장,부산돌상,부산출장돌상,전통돌상,부산돌잔치,부산돌정보... ",
#
# "bloggername": "파티해월",
#
# "bloggerlink": "http://blog.daum.net/sodam2",
#
# "postdate": "20130118"
#
#
#
# },
#
# {
#
# "title": "[데일리메일] [데일리메일]<b>문용준</b> 의혹조작 이유미 구속... ",
#
# "link": "http://blog.naver.com/mydailymail?Redirect=Log&amp;logNo=221040601586",
#
# "description": "",
#
# "bloggername": "mydailymail님의블로그",
#
# "bloggerlink": "http://blog.naver.com/mydailymail",
#
# "postdate": "20170629"
#
#
#
# },
#
# {
#
# "title": "&lt;티아라 바이 박은경&gt; <b>문용준</b> 신부님♥",
#
# "link": "http://blog.naver.com/tiara_park?Redirect=Log&amp;logNo=20116264410",
#
# "description": "[티아라 by 박은경] Hair. 윤상아 이사 M/Up. 강연진 부원장",
#
# "bloggername": "티아라 by 박은경",
#
# "bloggerlink": "http://blog.naver.com/tiara_park",
#
# "postdate": "20101102"
#
#
#
# },
#
# {
#
# "title": "인터넷 전문은행 사업 추진 방향성 6가지 - <b>문용준</b> SK C&amp;C 부장",
#
# "link": "http://blog.naver.com/nooyia?Redirect=Log&amp;logNo=220454073704",
#
# "description": "금융서비스의 진화에 따라 인터넷 은행(도입), 인터넷 전문은행(성장), 핀테크 은행(성숙)으로 단계별로 전환된다는 것. 특히 IT에서 DT(데이터 테크놀로지)로 기술의 변화가 이뤄지며 빅데이터와 핀테크... ",
#
# "bloggername": "소리나무",
#
# "bloggerlink": "http://blog.naver.com/nooyia",
#
# "postdate": "20150818"
#
#
#
# }
#
# ]
#
# }
#
# {
#
# "lastBuildDate": "Fri, 08 Sep 2017 13:54:41 +0900",
#
# "total": 518,
#
# "start": 11,
#
# "display": 10,
#
# "items": [
#
# {
#
# "title": "<b>문용준</b> <b>문용준</b>",
#
# "link": "http://blog.daum.net/runwaydrum/4308550",
#
# "description": "",
#
# "bloggername": "열심히 공부합니다...",
#
# "bloggerlink": "http://blog.daum.net/runwaydrum",
#
# "postdate": "20080524"
#
#
#
# },
#
# {
#
# "title": "세계 비보이 화려한 축제_<b>문용준</b>",
#
# "link": "http://blog.naver.com/lovelylegacy?Redirect=Log&amp;logNo=120110770550",
#
# "description": "",
#
# "bloggername": "보물선",
#
# "bloggerlink": "http://blog.naver.com/lovelylegacy",
#
# "postdate": "20100708"
#
#
#
# },
#
# {
#
# "title": "국민의당 이유미 이준서 최종 설계자는 누구인가?",
#
# "link": "http://impossibleproject.tistory.com/3195",
#
# "description": "<b>문용준</b>에 대한 특검을 함께 하자며 다시 물귀신 작전을 들고 나왔다. 자신들이 했던 엄청난 잘못에 대해 꼬리자르기에 여념이 없으면서 다시 한 번 <b>문용준</b>을 공격하겠다는 그 심보에 국민들은 분노한다. 최종... ",
#
# "bloggername": "또 다른 시선으로Another View",
#
# "bloggerlink": "http://impossibleproject.tistory.com/",
#
# "postdate": "20170627"
#
#
#
# },
#
# {
#
# "title": "박지원,녹취록 조작은 중요하지 않아! 문제는 취업특혜야!",
#
# "link": "http://blog.naver.com/socoolo1?Redirect=Log&amp;logNo=221047877299",
#
# "description": "과학적인 증명-ㅋㅋ <b>문용준</b> 제보조작 사건에 대한 검찰 수사 결과는이유미 씨의 단독 범행으로 결론 날 것이다.-신문기사로 검찰을 협박하는 박지원- 지랄 한다...그렇다면...국민의당...당대표는 이준서...... ",
#
# "bloggername": "쏘쿨",
#
# "bloggerlink": "http://blog.naver.com/socoolo1",
#
# "postdate": "20170710"
#
#
#
# },
#
# {
#
# "title": "[제주MBC 구성원 성명] 국토 최남단에서 외친다. 김장겸은... ",
#
# "link": "http://blog.naver.com/mbcfreedom?Redirect=Log&amp;logNo=221033339433",
#
# "description": "2017년 6월 20일 제주문화방송 구성원 일동 강순영 강흥주 강희철 고동희 고민찬 고수민 고일용 고재범 권혁태 김기호 김보성 김선희 김승범 김연화 김은영 김종화 김지은 김찬년 김항섭 김훈범 문승욱 <b>문용준</b>... ",
#
# "bloggername": "전국언론노조 MBC본부",
#
# "bloggerlink": "http://blog.naver.com/mbcfreedom",
#
# "postdate": "20170620"
#
#
#
# },
#
# {
#
# "title": "<b>문용준</b>님의 아기-인천아기사진 인천서구아기사진 가좌동... ",
#
# "link": "http://blog.naver.com/pje7080?Redirect=Log&amp;logNo=30136315121",
#
# "description": "아기의 50일은 6월4일입니다. 50일촬영때 뵙겠습니다. 가톨릭대학교 인천 성모병원을 통하여 50일무료촬영 &amp; 신생아 사진을 고급크리스탈로 만들어 드립니다.",
#
# "bloggername": "감각적인 아기사진 Kissing u baby studio",
#
# "bloggerlink": "http://blog.naver.com/pje7080",
#
# "postdate": "20120417"
#
#
#
# },
#
# {
#
# "title": "밴쿠버15회한인문화의날-스완가드스테디엄",
#
# "link": "http://blog.daum.net/chkwon1004/18358620",
#
# "description": "main=1&amp;boardId=5&amp;sbdtype=&amp;bdId=57849 “BC 주수상부터 갓난아이까지 함께 즐겼다” <b>문용준</b> 기자 myj@vanchosun.... <b>문용준</b> 기자 ***@*********.*** “제 15회 한인 문화의 날”이 밴쿠버한인문화협회(회장 석필원) 주최로... ",
#
# "bloggername": "학 마 을",
#
# "bloggerlink": "http://blog.daum.net/chkwon1004",
#
# "postdate": "20160810"
#
#
#
# },
#
# {
#
# "title": "[캐나다뉴스 &amp; CANADA NEWS] 한국인 방문자는 늘고... ",
#
# "link": "http://blog.naver.com/iacanada_?Redirect=Log&amp;logNo=221009867335",
#
# "description": "미국을 제외한 다른 나라 여행자들의 캐나다 방문은 58만5000건으로 월간 기준 6%의 상승률을 기록했다.출처 :벤쿠버 조선일보, <b>문용준</b> 기자 ***@*********.***",
#
# "bloggername": "PEQ 몬트리올 자녀무상교육",
#
# "bloggerlink": "http://blog.naver.com/iacanada_",
#
# "postdate": "20170520"
#
#
#
# },
#
# {
#
# "title": "[데일리메일] [데일리메일]‘국민의당 <b>문용준</b> 조작 면죄부’준... ",
#
# "link": "http://blog.naver.com/mydailymail?Redirect=Log&amp;logNo=221064700741",
#
# "description": "",
#
# "bloggername": "mydailymail님의블로그",
#
# "bloggerlink": "http://blog.naver.com/mydailymail",
#
# "postdate": "20170801"
#
#
#
# },
#
# {
#
# "title": "소통과 존중을 통한 시너지 극대화",
#
# "link": "http://blog.naver.com/youngunion_kfcc?Redirect=Log&amp;logNo=220822962808",
#
# "description": "지난 8월 18일, MG희망나눔 대학생 서포터즈 영유니온 2기의 8월 팀미션을 위해 새마을금고 중앙회 <b>문용준</b> 주임과 부산갈매기 팀이 인터뷰 자리를 가졌다 (위 사진) 새마을금고 중앙회 <b>문용준</b> 주임 <b>문용준</b>주임... ",
#
# "bloggername": "MG희망나눔 대학생 서포터즈 영유니온",
#
# "bloggerlink": "http://blog.naver.com/youngunion_kfcc",
#
# "postdate": "20160928"
#
#
#
# }
#
# ]
#
# }
#
# {
#
# "lastBuildDate": "Fri, 08 Sep 2017 13:54:42 +0900",
#
# "total": 518,
#
# "start": 21,
#
# "display": 10,
#
# "items": [
#
# {
#
# "title": "[금융전성시대, 인터넷은행 ]인터넷 전문은행 도입에 따른... ",
#
# "link": "http://skccblog.tistory.com/2605",
#
# "description": "변화를 대비하기 위해서는 글로벌 서비스를 할 수 있는 플랫폼과 다양한 데이터 분석 기법을 발전시켜야 하며, 소프트웨어 세상을 개척해 나갈 인재 양성이 중요하다. ♣ 글 : 프리미엄 서비스 팀 <b>문용준</b> 부장",
#
# "bloggername": "SK(주) C&C 블로그",
#
# "bloggerlink": "http://skccblog.tistory.com/",
#
# "postdate": "20151203"
#
#
#
# },
#
# {
#
# "title": "[제59회 현충일 추념식] 더 머물다 가고 싶은 곳, 국립서울현충원",
#
# "link": "http://mpva.tistory.com/2765",
#
# "description": "&lt;문상균, <b>문용준</b>님&gt; 다음으로 만난 분들은 현충일을 맞아 현충원을 방문한 문상균, <b>문용준</b> 부자입니다. Q : 어떻게 현충원에 오시게 되었나요? 문상균 : 국가와 민족을 위해서 몸을 마친 분들을 위한 추념식을... ",
#
# "bloggername": "국가보훈처 대표 블로그 - 훈터",
#
# "bloggerlink": "http://mpva.tistory.com/",
#
# "postdate": "20140612"
#
#
#
# },
#
# {
#
# "title": "외식업창업성공사례,자전거를 탄 풍경,버들골 이야기 그 두번째... ",
#
# "link": "http://blog.naver.com/ilovediacom?Redirect=Log&amp;logNo=220074078030",
#
# "description": "<b>문용준</b> 대표가 1999년 이태원의 7평짜리 권리금 없는 매장에서 시작해 건실한 프렌차이즈 주점으로 발전시킨 곳이기도 하다. 이곳엔 많은 프렌차이즈 관련 업계사람이나 창업쪽 사람들이 한때 많이 찾아들었다.... ",
#
# "bloggername": "창업칼럼니스트 창업블로그",
#
# "bloggerlink": "http://blog.naver.com/ilovediacom",
#
# "postdate": "20140728"
#
#
#
# },
#
# {
#
# "title": "블로그씨, 올해 일어났던 일 중, 내 인생에 가장 큰 영향을 준... ",
#
# "link": "http://blog.naver.com/rlfyd2ko?Redirect=Log&amp;logNo=220581642487",
#
# "description": "국가인가를 받아 출범하고 활동을 시작했다. 노승조회장님, 박종욱부회장님, 김해근,구수미,조성용,<b>문용준</b>, 그리고 나 이사진 모두 열심히 달려온 한해. 적극적으로 참여해준 회원님들 모두 감사^^",
#
# "bloggername": "한국통번역연구소 02-830-5151",
#
# "bloggerlink": "http://blog.naver.com/rlfyd2ko",
#
# "postdate": "20151229"
#
#
#
# },
#
# {
#
# "title": "정두언 안철수 종쳤다 발언, 국민의당 정계 개편이 다가온다",
#
# "link": "http://impossibleproject.tistory.com/3202",
#
# "description": "여기에 불에 기름을 끼얹듯 <b>문용준</b> 조작 사건이 터지며 국민의당은 존립 자체를 의심 받게 되었다. 호남 기반의 지자체 의원이 탈당하는 사태가 벌어진 것은 하나의 신호다. 대선이 끝난 후 민주당과 합치려는... ",
#
# "bloggername": "또 다른 시선으로Another View",
#
# "bloggerlink": "http://impossibleproject.tistory.com/",
#
# "postdate": "20170630"
#
#
#
# },
#
# {
#
# "title": "[8월 개인미션] 더위가 모지? 조국 독립의 역사 , 815 광복절",
#
# "link": "http://blog.naver.com/hyunju0434?Redirect=Log&amp;logNo=221083173675",
#
# "description": "저는 영유니온 부산팀을 담당하고 계신 새마을금고 중앙회 '<b>문용준</b> 주임님'에게 새마을금고 로고가 새겨진 물티슈를 지원받기로 하였습니당 ~ 그리하여 새마을금고중앙회 부산본부로 GO! GO! GO! 항상... ",
#
# "bloggername": "현두두 블로그",
#
# "bloggerlink": "http://blog.naver.com/hyunju0434",
#
# "postdate": "20170827"
#
#
#
# },
#
# {
#
# "title": "2017금산세계인삼엑스포 손님맞이 준비",
#
# "link": "http://blog.naver.com/2017worldginsengexpo?Redirect=Log&amp;logNo=221085522889",
#
# "description": "그 현장을 SNS <b>문용준</b> 서포터즈님이 드론으로 촬영하셨습니다. 함께 보실까요? 지금 금산은 방문손님들에게 보다 멋진 금산을 보여주기 위하여 휴일도 없이 행사준비에 최선을 다하고 있습니다. 인삼을... ",
#
# "bloggername": "2017금산세계인삼엑스포",
#
# "bloggerlink": "http://blog.naver.com/2017worldginsengexpo",
#
# "postdate": "20170830"
#
#
#
# },
#
# {
#
# "title": "은행의 IT시스템에 대한 이해",
#
# "link": "https://subokim.wordpress.com/2015/05/11/it_system_of_bank/",
#
# "description": "SK C&amp;C <b>문용준</b> 부장님이 Fi-ntechkorea.com에서 발표하신 자료를 첨부해봅니다. 인터넷전문은행(<b>문용준</b> SK C&amp;C, 2015.03) 그려주신 자료를 보면 은행 시스템의 추세가 계정계, 정보계... ",
#
# "bloggername": "IT의 중심에서",
#
# "bloggerlink": "https://subokim.wordpress.com/",
#
# "postdate": "20150511"
#
#
#
# },
#
# {
#
# "title": "국민의 당 &quot;이유미 당원 꼬리 짜르다가 손목 잘랐다”",
#
# "link": "http://spotnews.tistory.com/875",
#
# "description": "그러나 <b>문용준</b>씨에 대한 대국민 사과에도 불구하고 사건은 일파만파 커졌고 진상규명에 목소리가... 아들 <b>문용준</b>씨 비방과 관련해 모위원장의 지시로 허위자료를 만든 일로 오늘 남부지검 참고인 조사를 받게... ",
#
# "bloggername": "spotnews",
#
# "bloggerlink": "http://spotnews.tistory.com/",
#
# "postdate": "20170626"
#
#
#
# },
#
# {
#
# "title": "[데일리메일] [데일리메일]‘국민의당 <b>문용준</b> 조작 면죄부’준... ",
#
# "link": "http://blog.naver.com/mydailymail?Redirect=Log&amp;logNo=221064700431",
#
# "description": "",
#
# "bloggername": "mydailymail님의블로그",
#
# "bloggerlink": "http://blog.naver.com/mydailymail",
#
# "postdate": "20170801"
#
#
#
# }
#
# ]
#
# }
#
# {
#
# "lastBuildDate": "Fri, 08 Sep 2017 13:54:42 +0900",
#
# "total": 518,
#
# "start": 31,
#
# "display": 10,
#
# "items": [
#
# {
#
# "title": "밴조선-하버드대 세계번역대회 우승작 &lt;사랑은 꽃몸살... ",
#
# "link": "http://blog.daum.net/chkwon1004/18358544",
#
# "description": "<b>문용준</b> 기자의 차 한 잔 합시다 54_권천학 시인, 이청초 화백 한인문화협회 후원 오는 8월 14일까지... <b>문용준</b> 기자 ***@*********.*** 시회전 첫날인 7월 14일, 많은 사람들이 포트무디 아트센터를 찾았다. 이날... ",
#
# "bloggername": "학 마 을",
#
# "bloggerlink": "http://blog.daum.net/chkwon1004",
#
# "postdate": "20160717"
#
#
#
# },
#
# {
#
# "title": "[캐나다뉴스 &amp; CANADA NEWS] 캐나다 교수들은 얼마나 벌까?",
#
# "link": "http://blog.naver.com/iacanada_?Redirect=Log&amp;logNo=220993858959",
#
# "description": "2016년 전체 전일제 근로자의 중간 나이는 42세다. 한편 전국 교수들의 중간 급여는 2010/11년 9만2093달러에서 2016/17년도 9만8400달러로 6.8% 상승했다.출처: 밴쿠버 조선일보 <b>문용준</b> 기자 ***@*********.***",
#
# "bloggername": "PEQ 몬트리올 자녀무상교육",
#
# "bloggerlink": "http://blog.naver.com/iacanada_",
#
# "postdate": "20170428"
#
#
#
# },
#
# {
#
# "title": "2014년 8월",
#
# "link": "http://blog.naver.com/qoopoo11?Redirect=Log&amp;logNo=220118523256",
#
# "description": "그래도 너무 고맙게 술자리를 만들어 주시고 모두 참석해 주셨어요 아주대 앞에 있던 오봉자싸롱 이름이 너무 재밌고 처음 보는 스타일의 술집 제일 나이 많으시다고 한 턱 쏘신 &quot;<b>문용준</b>&quot;님 감사해용!! 동네에... ",
#
# "bloggername": "Golden_September",
#
# "bloggerlink": "http://blog.naver.com/qoopoo11",
#
# "postdate": "20140911"
#
#
#
# },
#
# {
#
# "title": "[사례로 본 인터넷 전문 은행 현황] 금융산업 경계를 허무는 IT... ",
#
# "link": "http://skccblog.tistory.com/2526",
#
# "description": "소프트웨어 세상에서 금융산업이란 경계는 없으므로 한국 IT기업들도 금융과 기술에 대한 인재를 키워야 세계적인 기업들이 변모해야 한다. * 글 : 프리미엄 서비스 팀 <b>문용준</b> 부장",
#
# "bloggername": "SK(주) C&C 블로그",
#
# "bloggerlink": "http://skccblog.tistory.com/",
#
# "postdate": "20151014"
#
#
#
# },
#
# {
#
# "title": "캐나다 신규 주택 계속해서 늘어날 듯",
#
# "link": "http://blog.naver.com/uncks01?Redirect=Log&amp;logNo=220832724103",
#
# "description": "상업이나 산업 시설 등 비주거 부문 건축허가액은 11.6% 늘어난 29억달러다. <b>문용준</b> 기자 ***@*********.*** 출처: 밴쿠버 조선일보 http://www.vanchosun.com/news/main/frame.php?main=1&amp;boardId=17&amp;bdId=58302&amp;sbdtype=",
#
# "bloggername": "호주이민,미국이민,캐나다이민 전문 (주)UNC",
#
# "bloggerlink": "http://blog.naver.com/uncks01",
#
# "postdate": "20161010"
#
#
#
# },
#
# {
#
# "title": "자랑스런 외국어 번역 행정사님.. 기억나는 대로 다 소개해... ",
#
# "link": "http://blog.naver.com/hdchoi721?Redirect=Log&amp;logNo=220533893975",
#
# "description": "5기 이시죠(ㅜ기억이..) 송영선 영어 번역 행정사님, <b>문용준</b> 영어 번역 행정사님, 엄은숙 중국어 번역... <b>문용준</b> 외번님은 일처리가 깔끔하고 정성어린 서식들로 유명하지요 엄은숙 외번님은 중국과 관련된 모든... ",
#
# "bloggername": "최희독의 번역행정사",
#
# "bloggerlink": "http://blog.naver.com/hdchoi721",
#
# "postdate": "20151110"
#
#
#
# },
#
# {
#
# "title": "경험이민(CEC) 신청 한층 빨라진다",
#
# "link": "http://uhakencollege.tistory.com/entry/%EA%B2%BD%ED%97%98%EC%9D%B4%EB%AF%BCCEC-%EC%8B%A0%EC%B2%AD-%ED%95%9C%EC%B8%B5-%EB%B9%A8%EB%9D%BC%EC%A7%84%EB%8B%A4",
#
# "description": "바 있다 CEC 를 통한 이민자가 7000 명선이 될 것이라는 게 이민당국의 예상이다 제이슨 케니 캐나다 이민부 장관은 “CEC 가 앞으로 이민자 유치에 중추적 역할을 하게 될 것 이라고 밝혔다 2012.04.19 <b>문용준</b> 기자",
#
# "bloggername": "캐나다컬리지 유학 and 취업",
#
# "bloggerlink": "http://uhakencollege.tistory.com/",
#
# "postdate": "20120419"
#
#
#
# },
#
# {
#
# "title": "텃밭 가꾸기",
#
# "link": "http://blog.daum.net/dolsalang/160",
#
# "description": "작년에 <b>문용준</b> 형이 지리산에서 보내온 것이다. 벽송사 골짜기 가득 피어 올라 산허리를 감싸던 구름들이 그립다. 오늘 석양은 참 고울 것 같다. 요즘, 밤하늘 보는 재미로 산다. 알몸으로 쪼그리고 앉아 하늘에... ",
#
# "bloggername": "목목재(目目齋)",
#
# "bloggerlink": "http://blog.daum.net/dolsalang",
#
# "postdate": "20110330"
#
#
#
# },
#
# {
#
# "title": "제2회 커뮤니티데이에 다녀왔다는...",
#
# "link": "http://zetlos.tistory.com/1179904367",
#
# "description": "ZDnet의 송경석 과장님과 SK C&amp;C의 <b>문용준</b> 부장님... Apple | iPhone 4S | Normal program | Pattern | 1/20sec | F/2.4 | 4.3mm | ISO-80 | Off Compulsory | 2012:07:07 16:21:26 생각보다 재미있고...... ",
#
# "bloggername": "꿈꾸는자의 생각의 파편들...",
#
# "bloggerlink": "http://zetlos.tistory.com/",
#
# "postdate": "20120708"
#
#
#
# },
#
# {
#
# "title": "인터넷전문은행, 금융서비스에 혁신이 가능할까?",
#
# "link": "http://catchrod.tistory.com/1515",
#
# "description": "에디토이 김국현 대표가 진행을 맡은 가운데 임정욱 센터장, 윤호영 다음카카오 TFT부사장, 이수진 금융연구원 연구위원, <b>문용준</b> SK C&amp;C 부장이 참석한 자리가 마련되었다. 여기서 나온 이야기를 통해... ",
#
# "bloggername": "공상제작소",
#
# "bloggerlink": "http://catchrod.tistory.com/",
#
# "postdate": "20150731"
#
#
#
# }
#
# ]
#
# }
